# %% [markdown]
# # **Import Necessary Libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import random

import os
import cv2
import keras
import tensorflow as tf
from PIL import Image
from tensorflow.keras.utils import load_img
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from keras.regularizers import l2

from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix,recall_score,precision_score
from keras.models import Sequential, Model
from keras.layers import Conv2D, MaxPooling2D, Activation, Dropout, Flatten, Dense, Input
from keras import optimizers
from tqdm.notebook import tqdm 
from tensorflow.keras.preprocessing.image import ImageDataGenerator

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # **Load the images and extract the meta data**

# %%
# Load the images.
path = "/kaggle/input/utkface-new/UTKFace"
files = os.listdir(path)

print("Total images:",len(files))
# Out:
# Total images: 23708

# %%
age_labels = []
gender_labels = []
image_paths = []

# Shuffle the image before loading it.
image_filenames = os.listdir(path)
random.shuffle(image_filenames)

for image in tqdm(image_filenames):
  # Extract the Meta Data from the images. 
  image_path = os.path.join(path, image)
  img_components = image.split('_')
  age_label = int(img_components[0])
  gender_label = int(img_components[1])

  # Append the image_path, age_label, and gender_label
  age_labels.append(age_label)
  gender_labels.append(gender_label)
  image_paths.append(image_path)
# Out:
#   0%|          | 0/23708 [00:00<?, ?it/s]

# %%
# Mapping function to convert 0 to 'Male' and 1 to 'Female'
def map_gender_label(gender):
    return 'Male' if gender == 0 else 'Female'

# Create a 2x5 subplot grid
fig, axes = plt.subplots(nrows=2, ncols=5, figsize=(10, 4))

# Flatten the axes array for easier indexing
axes = axes.flatten()

# Loop through the first 10 images and display them
for i in range(10):
    image_path = image_paths[i]
    image = cv2.imread(image_path)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    # Map gender label from 0/1 to 'Male'/'Female'
    gender_display = map_gender_label(gender_labels[i])
    
    axes[i].imshow(image)
    axes[i].axis('off')  # Remove axis ticks
    axes[i].set_title(f"Age: {age_labels[i]}\nGender: {gender_display}")

# Adjust layout to prevent overlap
plt.tight_layout()
plt.show()

# %%
images = pd.Series(list(image_paths), name="Image_Paths")
ages = pd.Series(list(age_labels), name="Ages")
genders = pd.Series(list(gender_labels), name="Genders")

df = pd.concat([images, ages, genders], axis=1)
df.head()
# Out:
#                                          Image_Paths  Ages  Genders
# 0  /kaggle/input/utkface-new/UTKFace/85_1_2_20170...    85        1
# 1  /kaggle/input/utkface-new/UTKFace/17_0_0_20170...    17        0
# 2  /kaggle/input/utkface-new/UTKFace/3_0_4_201612...     3        0
# 3  /kaggle/input/utkface-new/UTKFace/27_1_3_20170...    27        1
# 4  /kaggle/input/utkface-new/UTKFace/26_1_0_20170...    26        1

# %%
df.shape
# Out:
# (23708, 3)

# %%
# Save the dataset
#df.to_csv("images_df.csv")

# %%
# Count the occurrences of each gender
genders_count = df["Genders"].value_counts()
genders_count
# Out:
# Genders
# 0    12391
# 1    11317
# Name: count, dtype: int64

# %%
labels = ['Male', 'Female']
sizes = genders_count.values
colors = ['lightblue', 'lightpink']

# Create the pie chart
plt.figure(figsize=(8, 6))
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=140)
plt.title('Gender Distribution')
plt.show()

# %%
sns.distplot(df['Ages'],kde=True, bins=30);

# %% [markdown]
# # Models

# %%
# Read the images, reshape it to (128,128), 
# finnaly reshape the features as (Num of Sample, height, width, Num of channels).
def image_preprocessing(images):
    features = list()
    
    for image in tqdm(images):
        img = cv2.imread(image,0)
        # Convert the OpenCV image to a PIL image
        img = Image.fromarray(img)
        img = img.resize((128,128), Image.LANCZOS)
        img = np.array(img)
        features.append(img)
        
    features = np.array(features)
    features = features.reshape(len(features), 128, 128, 1)
    return features

# %%
X = image_preprocessing(df["Image_Paths"])
# Out:
#   0%|          | 0/23708 [00:00<?, ?it/s]

# %%
X.shape
# Out:
# (23708, 128, 128, 1)

# %%
# Normalizatio
X = X / 255.0

# %%
y_gender = np.array(df['Genders'])
y_age = np.array(df['Ages'])

# %% [markdown]
# # **Modeling**

# %% [markdown]
# ## **First Model**

# %%
input_shape = (128,128,1)
inputs = Input((input_shape))
conv_1 = Conv2D(32, kernel_size=(3, 3), activation='relu')(inputs)
max_1 = MaxPooling2D(pool_size=(2, 2))(conv_1)
conv_2 = Conv2D(64, kernel_size=(3, 3), activation='relu')(max_1)
max_2 = MaxPooling2D(pool_size=(2, 2))(conv_2)
conv_3 = Conv2D(128, kernel_size=(3, 3), activation='relu')(max_2)
max_3 = MaxPooling2D(pool_size=(2, 2))(conv_3)
conv_4 = Conv2D(256, kernel_size=(3, 3), activation='relu')(max_3)
max_4 = MaxPooling2D(pool_size=(2, 2))(conv_4)

flatten = Flatten()(max_4)

# fully connected layers
dense_1 = Dense(128, activation='relu')(flatten)
dense_2 = Dense(128, activation='relu')(flatten)

dropout_1 = Dropout(0.5)(dense_1)
dropout_2 = Dropout(0.5)(dense_2)

output_1 = Dense(1, activation='sigmoid', name='gender_out', kernel_regularizer=l2(0.001))(dropout_1)
output_2 = Dense(1, activation='relu', name='age_out', kernel_regularizer=l2(0.001))(dropout_2)

model_all = Model(inputs=[inputs], outputs=[output_1, output_2])

model_all.compile(
    loss={'gender_out': 'binary_crossentropy', 'age_out': 'mae'}, 
    optimizer='adam', 
    metrics={'gender_out': 'accuracy', 'age_out': 'mae'}
)

# %%
model_all.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 126, 126,  │        320 │ input_layer[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 63, 63,    │          0 │ conv2d[0][0]      │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 61, 61,    │     18,496 │ max_pooling2d[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 30, 30,    │          0 │ conv2d_1[0][0]    │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 28, 28,    │     73,856 │ max_pooling2d_1[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 14, 14,    │          0 │ conv2d_2[0][0]    │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 12, 12,    │    295,168 │ max_pooling2d_2[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 6, 6, 256) │          0 │ conv2d_3[0][0]    │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten (Flatten)   │ (None, 9216)      │          0 │ max_pooling2d_3[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 128)       │  1,179,776 │ flatten[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 128)       │  1,179,776 │ flatten[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 128)       │          0 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 128)       │          0 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gender_out (Dense)  │ (None, 1)         │        129 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ age_out (Dense)     │ (None, 1)         │        129 │ dropout_1[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 2,747,650 (10.48 MB)
#  Trainable params: 2,747,650 (10.48 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# plot the model
from tensorflow.keras.utils import plot_model
plot_model(model_all)

# %%
from keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# %%
history = model_all.fit(x=X, y=[y_gender, y_age],
                    batch_size=32, epochs=50, validation_split=0.2, 
                    callbacks=[early_stopping])
# Out:
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1727611615.656556  130376 service.cc:145] XLA service 0x559f62eb8db0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1727611615.656630  130376 service.cc:153]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1727611615.656637  130376 service.cc:153]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
#   7/593 ━━━━━━━━━━━━━━━━━━━━ 12s 22ms/step - age_out_mae: 30.0840 - gender_out_accuracy: 0.4198 - loss: 30.8714
# I0000 00:00:1727611625.467114  130376 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 37s 41ms/step - age_out_mae: 17.2071 - gender_out_accuracy: 0.5034 - loss: 17.9192 - val_age_out_mae: 14.4520 - val_gender_out_accuracy: 0.5249 - val_loss: 15.1451
# Epoch 2/50
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - age_out_mae: 14.3019 - gender_out_accuracy: 0.5850 - loss: 14.9557 - val_age_out_mae: 11.0825 - val_gender_out_accuracy: 0.7765 - val_loss: 11.5561
# Epoch 3/50
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - age_out_mae: 11.4687 - gender_out_accuracy: 0.7274 - loss: 12.0018 - val_age_out_mae: 10.0284 - val_gender_out_accuracy: 0.8028 - val_loss: 10.4534
# Epoch 4/50
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - age_out_mae: 10.3793 - gender_out_accuracy: 0.7469 - loss: 10.8872 - val_age_out_mae: 9.0781 - val_gender_out_accuracy: 0.8142 - val_loss: 9.4941
# Epoch 5/50
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - age_out_mae: 9.5406 - gender_out_accuracy: 0.7664 - loss: 10.0245 - val_age_out_mae: 8.4963 - val_gender_out_accuracy: 0.8332 - val_loss: 8.8674
# Epoch 6/50
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - age_out_mae: 8.9580 - gender_out_accuracy: 0.7828 - loss: 9.4086 - val_age_out_mae: 8.4229 - val_gender_out_accuracy: 0.8361 - val_loss: 8.7728
# Epoch 7/50
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - age_out_mae: 8.4334 - gender_out_accuracy: 0.8114 - loss: 8.8479 - val_age_out_mae: 7.1853 - val_gender_out_accuracy: 0.8574 - val_loss: 7.5035
# Epoch 8/50
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - age_out_mae: 8.1932 - gender_out_accuracy: 0.8182 - loss: 8.5903 - val_age_out_mae: 7.2734 - val_gender_out_accuracy: 0.8680 - val_loss: 7.5721
# Epoch 9/50
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - age_out_mae: 7.7960 - gender_out_accuracy: 0.8373 - loss: 8.1678 - val_age_out_mae: 7.1156 - val_gender_out_accuracy: 0.8655 - val_loss: 7.4130
# Epoch 10/50
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - age_out_mae: 7.5354 - gender_out_accuracy: 0.8437 - loss: 7.8819 - val_age_out_mae: 7.0668 - val_gender_out_accuracy: 0.8773 - val_loss: 7.3430
# Epoch 11/50
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - age_out_mae: 7.3178 - gender_out_accuracy: 0.8562 - loss: 7.6457 - val_age_out_mae: 6.7222 - val_gender_out_accuracy: 0.8802 - val_loss: 6.9853
# Epoch 12/50
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - age_out_mae: 7.1780 - gender_out_accuracy: 0.8573 - loss: 7.4988 - val_age_out_mae: 6.7533 - val_gender_out_accuracy: 0.8800 - val_loss: 7.0158
# Epoch 13/50
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - age_out_mae: 7.0423 - gender_out_accuracy: 0.8610 - loss: 7.3553 - val_age_out_mae: 6.7683 - val_gender_out_accuracy: 0.8836 - val_loss: 7.0239
# Epoch 14/50
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - age_out_mae: 6.9176 - gender_out_accuracy: 0.8730 - loss: 7.2143 - val_age_out_mae: 6.6202 - val_gender_out_accuracy: 0.8739 - val_loss: 6.9001
# Epoch 15/50
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - age_out_mae: 6.7686 - gender_out_accuracy: 0.8770 - loss: 7.0648 - val_age_out_mae: 6.6211 - val_gender_out_accuracy: 0.8865 - val_loss: 6.8733
# Epoch 16/50
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - age_out_mae: 6.6426 - gender_out_accuracy: 0.8806 - loss: 6.9252 - val_age_out_mae: 7.3410 - val_gender_out_accuracy: 0.8876 - val_loss: 7.5891
# Epoch 17/50
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - age_out_mae: 6.5953 - gender_out_accuracy: 0.8787 - loss: 6.8820 - val_age_out_mae: 7.1369 - val_gender_out_accuracy: 0.8878 - val_loss: 7.3865
# Epoch 18/50
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - age_out_mae: 6.4398 - gender_out_accuracy: 0.8861 - loss: 6.7117 - val_age_out_mae: 6.9225 - val_gender_out_accuracy: 0.8899 - val_loss: 7.1716
# Epoch 19/50
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - age_out_mae: 6.3563 - gender_out_accuracy: 0.8906 - loss: 6.6208 - val_age_out_mae: 6.6682 - val_gender_out_accuracy: 0.8842 - val_loss: 6.9319
# Epoch 20/50
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - age_out_mae: 6.0913 - gender_out_accuracy: 0.8901 - loss: 6.3542 - val_age_out_mae: 6.9830 - val_gender_out_accuracy: 0.8925 - val_loss: 7.2310
# Epoch 21/50
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - age_out_mae: 5.9921 - gender_out_accuracy: 0.8884 - loss: 6.2586 - val_age_out_mae: 6.5471 - val_gender_out_accuracy: 0.8868 - val_loss: 6.8066
# Epoch 22/50
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - age_out_mae: 6.0062 - gender_out_accuracy: 0.8932 - loss: 6.2666 - val_age_out_mae: 6.6809 - val_gender_out_accuracy: 0.8895 - val_loss: 6.9320
# Epoch 23/50
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - age_out_mae: 5.9555 - gender_out_accuracy: 0.8995 - loss: 6.1971 - val_age_out_mae: 6.7342 - val_gender_out_accuracy: 0.8878 - val_loss: 6.9988
# Epoch 24/50
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - age_out_mae: 5.8217 - gender_out_accuracy: 0.8982 - loss: 6.0613 - val_age_out_mae: 6.6977 - val_gender_out_accuracy: 0.8899 - val_loss: 6.9491
# Epoch 25/50
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - age_out_mae: 5.9115 - gender_out_accuracy: 0.8984 - loss: 6.1530 - val_age_out_mae: 6.8494 - val_gender_out_accuracy: 0.8882 - val_loss: 7.1140
# Epoch 26/50
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - age_out_mae: 5.6512 - gender_out_accuracy: 0.9055 - loss: 5.8797 - val_age_out_mae: 6.7477 - val_gender_out_accuracy: 0.8836 - val_loss: 7.0123
# Epoch 27/50
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - age_out_mae: 5.6504 - gender_out_accuracy: 0.9079 - loss: 5.8783 - val_age_out_mae: 6.7378 - val_gender_out_accuracy: 0.8870 - val_loss: 6.9984
# Epoch 28/50
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - age_out_mae: 5.5825 - gender_out_accuracy: 0.9077 - loss: 5.8055 - val_age_out_mae: 7.1802 - val_gender_out_accuracy: 0.8893 - val_loss: 7.4519
# Epoch 29/50
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - age_out_mae: 5.5246 - gender_out_accuracy: 0.9120 - loss: 5.7393 - val_age_out_mae: 6.7003 - val_gender_out_accuracy: 0.8880 - val_loss: 6.9932
# Epoch 30/50
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - age_out_mae: 5.3603 - gender_out_accuracy: 0.9129 - loss: 5.5714 - val_age_out_mae: 6.7645 - val_gender_out_accuracy: 0.8851 - val_loss: 7.0565
# Epoch 31/50
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - age_out_mae: 5.4172 - gender_out_accuracy: 0.9131 - loss: 5.6304 - val_age_out_mae: 6.7372 - val_gender_out_accuracy: 0.8796 - val_loss: 7.0469

# %%
history.history.keys()
# Out:
# dict_keys(['age_out_mae', 'gender_out_accuracy', 'loss', 'val_age_out_mae', 'val_gender_out_accuracy', 'val_loss'])

# %%
# plot results for gender
acc = history.history['gender_out_accuracy']
val_acc = history.history['val_gender_out_accuracy']
epochs = range(len(acc))

plt.plot(epochs, acc, 'b', label='Training Accuracy')
plt.plot(epochs, val_acc, 'r', label='Validation Accuracy')
plt.title('Accuracy Graph')
plt.legend()
plt.figure()

# plot results for age
loss = history.history['age_out_mae']
val_loss = history.history['val_age_out_mae']
epochs = range(len(loss))

plt.plot(epochs, loss, 'b', label='Training Loss')
plt.plot(epochs, val_loss, 'r', label='Validation Loss')
plt.title('Loss Graph')
plt.legend()
plt.show()

# %%
model_all.save("model_all.h5")

# %% [markdown]
# ## **Evaluate the Model**

# %%
def get_image_features(image):
  img = cv2.imread(image, 0)
  img = Image.fromarray(img)
  img = img.resize((128,128), Image.LANCZOS)
  img = np.array(img)
  img = img.reshape(1, 128, 128, 1)
  img = img / 255.0
  return img

# %%
# Load Some images to test with
path_test = '/kaggle/input/utkface-new/crop_part1'
age_labels_test = []
gender_labels_test = []
image_paths_test = []

image_filenames_1 = os.listdir(path_test)
random.shuffle(image_filenames_1)

for image in tqdm(image_filenames_1):
  image_path_test = os.path.join(path_test, image)
  img_components_test = image.split('_')
  age_label_test = int(img_components_test[0])
  gender_label_test = int(img_components_test[1])

  # Append the image_path, age_label, and gender_label
  age_labels_test.append(age_label_test)
  gender_labels_test.append(gender_label_test)
  image_paths_test.append(image_path_test)
# Out:
#   0%|          | 0/9780 [00:00<?, ?it/s]

# %%
# Create a figure with 2 rows and 5 columns
fig, axes = plt.subplots(2, 5, figsize=(15, 6))  # Adjust figsize as needed

for i in range(10):
    img_to_test = image_paths_test[i]  # Use the current index 'i' to select a different image
    features = get_image_features(img_to_test)
    pred = model_all.predict(features)

    gender_pred = map_gender_label(round(pred[0][0][0]))
    age_pred = round(pred[1][0][0])
    
    # Load the image
    img = np.array(load_img(img_to_test))
    
    # Display the image in the corresponding subplot
    ax = axes[i // 5, i % 5]  # Calculate the position in the grid
    ax.imshow(img)
    
    # Include actual labels in the title
    ax.set_title(f'Predicted Age: {age_pred}\n'
                 f'Actual Age: {age_labels_test[i]}\n'
                 f'Predicted Gender: {gender_pred}\n'
                 f'Actual Gender: {map_gender_label(gender_labels_test[i])}', 
                 fontsize=10, pad=10)
    
    ax.axis('off')  # Turn off axis

plt.tight_layout()  # Adjust layout for better spacing
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 503ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step

# %%
# Lists to store predictions
predicted_genders = []
predicted_ages = []

# Iterate over some test images
for img_to_test in image_paths_test[:3000]:
    features = get_image_features(img_to_test)  # Preprocess the image
    pred = model_all.predict(features, verbose=0)

    # Get predictions
    predicted_genders.append(round(pred[0][0][0]))  # Gender prediction
    predicted_ages.append(round(pred[1][0][0]))      # Age prediction

# Convert lists to numpy arrays for accuracy calculation
predicted_genders = np.array(predicted_genders)
predicted_ages = np.array(predicted_ages)

# Calculate accuracy for gender
gender_accuracy = accuracy_score(gender_labels_test[:3000], predicted_genders)
print(f'Test Gender Accuracy: {gender_accuracy * 100:.2f}%')

# Optionally, if you want to calculate a metric for age predictions:
# For age, you may want to use a different metric (e.g., Mean Absolute Error)
age_mae = mean_squared_error(age_labels_test[:3000], predicted_ages) # MAE for age predictions
age_rmae = np.sqrt(age_mae)
print(f'Mean Absolute Error for Age: {age_mae:.2f}')
print(f'Root Mean Absolute Error for Age: {age_rmae:.2f}')
# Out:
# Test Gender Accuracy: 86.30%
# Mean Absolute Error for Age: 47.69
# Root Mean Absolute Error for Age: 6.91

# %%
report = classification_report(gender_labels_test[:3000], predicted_genders)
print("Classification Report")
print(report)
# Out:
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.85      0.85      0.85      1341
#            1       0.88      0.88      0.88      1659
#
#     accuracy                           0.86      3000
#    macro avg       0.86      0.86      0.86      3000
# weighted avg       0.86      0.86      0.86      3000

# %%
# Confusion matrix
conf_matrix = confusion_matrix(gender_labels_test[:3000], predicted_genders)
print("Confusion Matrix")
print(conf_matrix)

# Plotting confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Male', 'Female'], yticklabels=['Male', 'Female'])
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.title('Confusion Matrix')
plt.show()
# Out:
# Confusion Matrix
# [[1136  205]
#  [ 206 1453]]

# %% [markdown]
# ## **Second Model**

# %%
input_shape = (128,128,1)
inputs = Input((input_shape))
conv_1 = Conv2D(32, kernel_size=(3, 3), activation='relu')(inputs)
conv_2 = Conv2D(32, kernel_size=(3, 3), activation='relu')(conv_1)
max_1 = MaxPooling2D(pool_size=(2, 2))(conv_2)

conv_3 = Conv2D(64, kernel_size=(3, 3), activation='relu')(max_1)
conv_4 = Conv2D(64, kernel_size=(3, 3), activation='relu')(conv_3)
max_2 = MaxPooling2D(pool_size=(2, 2))(conv_4)


flatten = Flatten()(max_2)

# fully connected layers
dense_1 = Dense(128, activation='relu')(flatten)
dense_2 = Dense(128, activation='relu')(flatten)

dropout_1 = Dropout(0.5)(dense_1)
dropout_2 = Dropout(0.5)(dense_2)

output_1 = Dense(1, activation='sigmoid', name='gender_out', kernel_regularizer=l2(0.001))(dropout_1)
output_2 = Dense(1, activation='relu', name='age_out', kernel_regularizer=l2(0.001))(dropout_2)

model_all2 = Model(inputs=[inputs], outputs=[output_1, output_2])

model_all2.compile(
    loss={'gender_out': 'binary_crossentropy', 'age_out': 'mae'}, 
    optimizer='adam', 
    metrics={'gender_out': 'accuracy', 'age_out': 'mae'}
)

# %%
model_all2.summary()
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 126, 126,  │        320 │ input_layer_1[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 124, 124,  │      9,248 │ conv2d_4[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_4     │ (None, 62, 62,    │          0 │ conv2d_5[0][0]    │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 60, 60,    │     18,496 │ max_pooling2d_4[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 58, 58,    │     36,928 │ conv2d_6[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_5     │ (None, 29, 29,    │          0 │ conv2d_7[0][0]    │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_1 (Flatten) │ (None, 53824)     │          0 │ max_pooling2d_5[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 128)       │  6,889,600 │ flatten_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 128)       │  6,889,600 │ flatten_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 128)       │          0 │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 128)       │          0 │ dense_3[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gender_out (Dense)  │ (None, 1)         │        129 │ dropout_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ age_out (Dense)     │ (None, 1)         │        129 │ dropout_3[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 13,844,450 (52.81 MB)
#  Trainable params: 13,844,450 (52.81 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
plot_model(model_all2)

# %%
history2 = model_all2.fit(x=X, y=[y_gender, y_age],
                    batch_size=32, epochs=25, validation_split=0.2)
# Out:
# Epoch 1/25
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 37s 47ms/step - age_out_mae: 15.5367 - gender_out_accuracy: 0.6194 - loss: 16.2110 - val_age_out_mae: 10.2533 - val_gender_out_accuracy: 0.7995 - val_loss: 10.6661
# Epoch 2/25
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 20s 33ms/step - age_out_mae: 10.3573 - gender_out_accuracy: 0.8196 - loss: 10.7517 - val_age_out_mae: 8.1843 - val_gender_out_accuracy: 0.8606 - val_loss: 8.4772
# Epoch 3/25
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 20s 33ms/step - age_out_mae: 9.1541 - gender_out_accuracy: 0.8500 - loss: 9.4898 - val_age_out_mae: 7.7048 - val_gender_out_accuracy: 0.8730 - val_loss: 7.9721
# Epoch 4/25
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 19s 33ms/step - age_out_mae: 8.5966 - gender_out_accuracy: 0.8729 - loss: 8.8837 - val_age_out_mae: 7.4118 - val_gender_out_accuracy: 0.8813 - val_loss: 7.6708
# Epoch 5/25
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 20s 33ms/step - age_out_mae: 8.0896 - gender_out_accuracy: 0.8851 - loss: 8.3566 - val_age_out_mae: 7.2627 - val_gender_out_accuracy: 0.8798 - val_loss: 7.5325
# Epoch 6/25
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 20s 33ms/step - age_out_mae: 7.9291 - gender_out_accuracy: 0.8962 - loss: 8.1694 - val_age_out_mae: 7.1353 - val_gender_out_accuracy: 0.8925 - val_loss: 7.3796
# Epoch 7/25
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 20s 33ms/step - age_out_mae: 7.5534 - gender_out_accuracy: 0.9029 - loss: 7.7750 - val_age_out_mae: 7.0176 - val_gender_out_accuracy: 0.8948 - val_loss: 7.2501
# Epoch 8/25
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 20s 33ms/step - age_out_mae: 7.3482 - gender_out_accuracy: 0.9158 - loss: 7.5491 - val_age_out_mae: 6.7293 - val_gender_out_accuracy: 0.8986 - val_loss: 6.9665
# Epoch 9/25
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 20s 33ms/step - age_out_mae: 7.1574 - gender_out_accuracy: 0.9236 - loss: 7.3381 - val_age_out_mae: 7.7104 - val_gender_out_accuracy: 0.9015 - val_loss: 7.9501
# Epoch 10/25
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 19s 33ms/step - age_out_mae: 7.1876 - gender_out_accuracy: 0.9327 - loss: 7.3519 - val_age_out_mae: 6.6547 - val_gender_out_accuracy: 0.8952 - val_loss: 6.9039
# Epoch 11/25
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 19s 33ms/step - age_out_mae: 6.7712 - gender_out_accuracy: 0.9372 - loss: 6.9209 - val_age_out_mae: 6.7691 - val_gender_out_accuracy: 0.9003 - val_loss: 7.0405
# Epoch 12/25
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 19s 33ms/step - age_out_mae: 6.7885 - gender_out_accuracy: 0.9401 - loss: 6.9251 - val_age_out_mae: 6.7226 - val_gender_out_accuracy: 0.9013 - val_loss: 6.9821
# Epoch 13/25
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 20s 33ms/step - age_out_mae: 6.4781 - gender_out_accuracy: 0.9495 - loss: 6.5941 - val_age_out_mae: 6.7232 - val_gender_out_accuracy: 0.9049 - val_loss: 6.9904
# Epoch 14/25
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 19s 33ms/step - age_out_mae: 6.3785 - gender_out_accuracy: 0.9522 - loss: 6.4882 - val_age_out_mae: 6.6739 - val_gender_out_accuracy: 0.8965 - val_loss: 6.9665
# Epoch 15/25
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 19s 33ms/step - age_out_mae: 6.1384 - gender_out_accuracy: 0.9562 - loss: 6.2403 - val_age_out_mae: 6.5776 - val_gender_out_accuracy: 0.8996 - val_loss: 6.8735
# Epoch 16/25
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 19s 33ms/step - age_out_mae: 6.0241 - gender_out_accuracy: 0.9543 - loss: 6.1186 - val_age_out_mae: 6.7275 - val_gender_out_accuracy: 0.9000 - val_loss: 7.0657
# Epoch 17/25
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 19s 33ms/step - age_out_mae: 5.9326 - gender_out_accuracy: 0.9617 - loss: 6.0182 - val_age_out_mae: 6.7457 - val_gender_out_accuracy: 0.9009 - val_loss: 7.1140
# Epoch 18/25
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 20s 33ms/step - age_out_mae: 5.9676 - gender_out_accuracy: 0.9642 - loss: 6.0500 - val_age_out_mae: 6.9305 - val_gender_out_accuracy: 0.9019 - val_loss: 7.3086
# Epoch 19/25
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 19s 33ms/step - age_out_mae: 5.8228 - gender_out_accuracy: 0.9652 - loss: 5.8978 - val_age_out_mae: 6.7181 - val_gender_out_accuracy: 0.8988 - val_loss: 7.0875
# Epoch 20/25
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 19s 33ms/step - age_out_mae: 5.7257 - gender_out_accuracy: 0.9665 - loss: 5.7993 - val_age_out_mae: 6.7804 - val_gender_out_accuracy: 0.9009 - val_loss: 7.1476
# Epoch 21/25
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 19s 33ms/step - age_out_mae: 5.5543 - gender_out_accuracy: 0.9690 - loss: 5.6226 - val_age_out_mae: 6.9820 - val_gender_out_accuracy: 0.8994 - val_loss: 7.3609
# Epoch 22/25
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 19s 33ms/step - age_out_mae: 5.5575 - gender_out_accuracy: 0.9710 - loss: 5.6220 - val_age_out_mae: 6.7965 - val_gender_out_accuracy: 0.9011 - val_loss: 7.1811
# Epoch 23/25
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 19s 33ms/step - age_out_mae: 5.5375 - gender_out_accuracy: 0.9699 - loss: 5.6084 - val_age_out_mae: 6.8891 - val_gender_out_accuracy: 0.8967 - val_loss: 7.3493
# Epoch 24/25
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 19s 33ms/step - age_out_mae: 5.4444 - gender_out_accuracy: 0.9698 - loss: 5.5089 - val_age_out_mae: 6.8155 - val_gender_out_accuracy: 0.9028 - val_loss: 7.2416
# Epoch 25/25
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 19s 33ms/step - age_out_mae: 5.3647 - gender_out_accuracy: 0.9727 - loss: 5.4227 - val_age_out_mae: 6.7559 - val_gender_out_accuracy: 0.9026 - val_loss: 7.1857

# %%
# plot results for gender
acc = history2.history['gender_out_accuracy']
val_acc = history2.history['val_gender_out_accuracy']
epochs = range(len(acc))

plt.plot(epochs, acc, 'b', label='Training Accuracy')
plt.plot(epochs, val_acc, 'r', label='Validation Accuracy')
plt.title('Accuracy Graph')
plt.legend()
plt.figure()

# plot results for age
loss = history2.history['age_out_mae']
val_loss = history2.history['val_age_out_mae']
epochs = range(len(loss))

plt.plot(epochs, loss, 'b', label='Training Loss')
plt.plot(epochs, val_loss, 'r', label='Validation Loss')
plt.title('Loss Graph')
plt.legend()
plt.show()

# %%
# Create a figure with 2 rows and 5 columns
fig, axes = plt.subplots(2, 5, figsize=(15, 6))  # Adjust figsize as needed

for i in range(10):
    img_to_test = image_paths_test[i]  # Use the current index 'i' to select a different image
    features = get_image_features(img_to_test)
    pred = model_all2.predict(features)

    gender_pred = map_gender_label(round(pred[0][0][0]))
    age_pred = round(pred[1][0][0])
    
    # Load the image
    img = np.array(load_img(img_to_test))
    
    # Display the image in the corresponding subplot
    ax = axes[i // 5, i % 5]  # Calculate the position in the grid
    ax.imshow(img)
    
    # Include actual labels in the title
    ax.set_title(f'Predicted Age: {age_pred}\n'
                 f'Actual Age: {age_labels_test[i]}\n'
                 f'Predicted Gender: {gender_pred}\n'
                 f'Actual Gender: {map_gender_label(gender_labels_test[i])}', 
                 fontsize=10, pad=10)
    
    ax.axis('off')  # Turn off axis

plt.tight_layout()  # Adjust layout for better spacing
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 502ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step

# %%
# Lists to store predictions
predicted_genders = []
predicted_ages = []

# Iterate over some test images
for img_to_test in image_paths_test[3000:6000]:
    features = get_image_features(img_to_test)  # Preprocess the image
    pred = model_all2.predict(features, verbose=0)

    # Get predictions
    predicted_genders.append(round(pred[0][0][0]))  # Gender prediction
    predicted_ages.append(round(pred[1][0][0]))      # Age prediction

# Convert lists to numpy arrays for accuracy calculation
predicted_genders = np.array(predicted_genders)
predicted_ages = np.array(predicted_ages)

# Calculate accuracy for gender
gender_accuracy = accuracy_score(gender_labels_test[3000:6000], predicted_genders)
print(f'Test Gender Accuracy: {gender_accuracy * 100:.2f}%')

# Optionally, if you want to calculate a metric for age predictions:
# For age, you may want to use a different metric (e.g., Mean Absolute Error)
age_mae = mean_squared_error(age_labels_test[3000:6000], predicted_ages) # MAE for age predictions
age_rmae = np.sqrt(age_mae)
print(f'Mean Absolute Error for Age: {age_mae:.2f}')
print(f'Root Mean Absolute Error for Age: {age_rmae:.2f}')
# Out:
# Test Gender Accuracy: 96.40%
# Mean Absolute Error for Age: 34.92
# Root Mean Absolute Error for Age: 5.91

# %%
report = classification_report(gender_labels_test[3000:6000], predicted_genders)
print("Classification Report")
print(report)
# Out:
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96      1360
#            1       0.96      0.97      0.97      1639
#            3       0.00      0.00      0.00         1
#
#     accuracy                           0.96      3000
#    macro avg       0.64      0.64      0.64      3000
# weighted avg       0.96      0.96      0.96      3000

# %%
# Confusion matrix
conf_matrix = confusion_matrix(gender_labels_test[3000:6000], predicted_genders)
print("Confusion Matrix")
print(conf_matrix)

# Plotting confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Male', 'Female'], yticklabels=['Male', 'Female'])
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.title('Confusion Matrix')
plt.show()
# Out:
# Confusion Matrix
# [[1301   59    0]
#  [  48 1591    0]
#  [   0    1    0]]

# %%
model_all2.save("model_all2.h5")
